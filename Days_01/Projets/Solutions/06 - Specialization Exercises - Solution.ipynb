# %% [markdown]
# # Specialization Exercises

# %% [markdown]
# ### Exercise 1
#
# Given the variables.
# ```Python
# name = 'Charles'
# age = 42
# ```
# 0. Copy the variables in the cell below.
# 1. Use an f-string to print `Charles is 42 years old`
# 2. Change the values of `name` and `age` and execute again.

# %%
name = 'Charles'
age = 42

# %%
print(f'{name} is {age} years old')
# Out:
# Charles is 42 years old

# %% [markdown]
# ### Exercise 2 (Challenging)
# Given the variables.
# ```Python
# r = 2
# pi = 3.14
# ```
# You need the following formula calculating the area of a cirle.
# $$ a = pi\times r^2 $$
# 0. Copy the variables in the cell below.
# 1. Use an f-string to print the area of the circle along with some text.
# HINT: $\times$ is `*` and $^2$ is `**2`

# %%
r = 2
pi = 3.14

print(f'Radius: {r}, area: {pi*r**2}')
# Out:
# Radius: 2, area: 12.56

# %%
r = 2
pi = 3.14

area = pi*r**2

print(f'Radius: {r}, area: {area}')
# Out:
# Radius: 2, area: 12.56
