# %% [markdown]
# # Specialization Exercises / NICE-TO-HAVE
#
# These exercises are for you if you want to learn more about using Notebooks for calculating formulas.
#
# You do not need to make them unless you want to.

# %% [markdown]
# ### Exercise 1
# <img src="img/square.png" alt="Area of square" width="200"/>
#
# 1. Make a formula for the area
# 2. Make a formula for the perimeter

# %% [markdown]
# ### Exercise 2
# <img src="img/trapezoid.png" alt="Area of trapezoid" width="200"/>
# Make a formula for the area

# %% [markdown]
# ### Exercise 3
# <img src="img/parallelogram.png" alt="Area of parallelogram" width="200"/>
# Make a formula for the area
