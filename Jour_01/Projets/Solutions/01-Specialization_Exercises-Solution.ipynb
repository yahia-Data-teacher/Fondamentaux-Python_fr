# %% [markdown]
# <a href="https://colab.research.google.com/github/yahia-kplr/Fondamentaux-Python_fr/blob/main/Jour_01/Projets/Solutions/01-Specialization_Exercises-Solution.ipynb" target="_blank"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Specialization Exercises / NICE-TO-HAVE
#
# These exercises are for you if you want to learn more about using Notebooks for calculating formulas.
#
# You do not need to make them unless you want to.

# %% [markdown]
# ### Exercice 1
# <img src="../img/square.png" alt="Aire du carré" width="200"/>
#
# 1. Faites une formule pour la zone
# 2. Faites une formule pour le périmètre

# %%
x = 4

area = x**2
area
# Out:
# 16

# %%
x = 4

perimeter = 4*x
perimeter
# Out:
# 16

# %% [markdown]
# ### Exercice 2
# <img src="../img/trapezoid.png" alt="Aire du trapèze" width="200"/>
#
# Faire une formule pour la zone

# %%
a = 3
b = 4
h = 2

area = 1/2*(a + b)*h
area
# Out:
# 7.0

# %% [markdown]
# ### Exercice 3
# <img src="../img/parallelogram.png" alt="Aire du parallélogramme" width="200"/>
#
# Faire une formule pour la zone

# %%
b = 5
h = 3

area = b*h
area
# Out:
# 15
