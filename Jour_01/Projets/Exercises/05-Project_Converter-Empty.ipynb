# %% [markdown]
# <a href="https://colab.research.google.com/github/yahia-kplr/Fondamentaux-Python_fr/blob/main/Jour_01/Projets/Exercises/05-Project_Converter-Empty.ipynb" target="_blank"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project Converter
#
# Create a converter from fahrenheit to celcius using the formula
#
# $$ °C = (°F − 32) \times 5/9 $$

# %% [markdown]
# ### Étape 1 : saisieDemandez à l'utilisateur d'entrer une température en Fahrenheit.

# %% [markdown]
# ### Étape 2 : ConvertirConvertir l'entrée en `float`

# %% [markdown]
# ### Étape 3 : CalculerUtilisez la formule pour calculer la température en degrés Celsius

# %% [markdown]
# ### Étape 4 : ImprimezImprimer le résultat à l'utilisateur
