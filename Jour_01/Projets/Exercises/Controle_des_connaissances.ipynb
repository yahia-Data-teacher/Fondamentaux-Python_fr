# %% [markdown]
# <a href="https://colab.research.google.com/github/kplr-training/Fondamentaux-Python/blob/main/Jour_01/Projets/Exercises/Controle_des_connaissances.ipynb" target="_blank"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <strong><h3><span>Exercice 1</span></h3></strong>
# <p>Écrivez un programme pour saisir deux nombres de l'utilisateur et calculer leur somme. L'utilisateur doit donc entrer deux valeurs, puis le programme calcule leur somme</p>
# <div class="style-msg2"><div class="msgtitle">Exemple :</div><div class="sb-msg"><strong><em>Données d'entrée&nbsp;</em></strong><br><ul class="iconlist none"><li>Saisir le premier nombre : 7</li><li>Saisir le deuxième nombre : 8</li></ul><br><strong><em>Données de sortie</em></strong><br><ul class="iconlist none"><li>La somme = 15</li></ul></div></div>

# %%
#Solution

# %% [markdown]
# <strong><div class="fancy-title title-bottom-border"><h3><span>Exercice 2</span></h3></div></strong>
# <p>Écrivez un programme pour saisir la longueur et la largeur d'un rectangle et calculer son périmètre.</p>
# <br>
# <strong><p align="center">perimetre = 2(longueur+largeur)&nbsp;</p></strong>
# <div class="msgtitle">Exemple :</div><div class="sb-msg"><strong><em>Données d'entrée&nbsp;</em></strong>
# <ul class="iconlist none"><li>Saisir la longueur : 5</li>
# <li>Saisir la largeur : 10</li></ul>
# <strong><em>Données de sortie</em></strong>
# <br>
# <ul class="iconlist none"><li>le périmètre = 30</li></ul></div>

# %%
#Solution

# %% [markdown]
# <strong><h3><span>Exercice 3</span></h3></strong>
# <p>Écrivez un programme pour saisir la longueur en centimètres et convertissez-le en mètres et en kilomètres.</p>
# <div class="style-msg2"><div class="msgtitle">Exemple :</div>
# <div class="sb-msg"><strong>
# <em>Données d'entrée&nbsp;</em></strong>
# <ul class="iconlist none"><li>Saisir la longueur en centimètres : 1000</li></ul>
# <strong><em>Données de sortie</em></strong>
# <ul class="iconlist none"><li>Longueur en mètres = 10 m</li><li>Longueur en Kilomètres = 0.01 km</li></ul></div></div>

# %%
#Solution

# %% [markdown]
# <strong><div class="fancy-title title-bottom-border"><h3><span>Exercice 4</span></h3></div></strong>
# <p>Écrivez un programme pour saisir le nombre de jours de l'utilisateur et convertissez-le en années, semaines et jours.</p>
# <div class="style-msg2"><div class="msgtitle">
# <strong>Exemple :</strong>
# </div><div class="sb-msg"><strong><em>Données d'entrée&nbsp;</em></strong><br><ul class="iconlist none"><li>Saisir le nombre de jours : 373</li></ul><br><strong><em>Données de sortie</em></strong><br><ul class="iconlist none"><li>1 an(s)</li><li>1 semaine(s)</li><li>Jour(s) : 1 jour(s)</li></ul></div></div>

# %%
#solution

# %% [markdown]
# <strong><div class="fancy-title title-bottom-border"><h3><span>Exercice 5</span></h3></div></strong>
# <p>Écrivez un programme pour saisir deux nombres de l'utilisateur et trouvez leur puissance.</p>
# <strong><div class="style-msg2"><div class="msgtitle">Exemple :</div></strong><div class="sb-msg"><strong><em>Données d'entrée&nbsp;</em></strong><br><ul class="iconlist none"><li>Saisir la base : 6</li><li>Saisir l'exposant : 2</li></ul><br><strong><em>Données de sortie</em></strong><br><ul class="iconlist none"><li>6 ^ 2 = 36</li></ul></div></div>

# %%
#solution

# %% [markdown]
# <strong><div class="fancy-title title-bottom-border"><h3><span>Exercice 6</span></h3></div></strong>
# <p>Écrivez un programme pour saisir un nombre et calculer sa racine carrée.</p>
# <strong><div class="style-msg2"><div class="msgtitle">Exemple :</div></strong><div class="sb-msg"><strong><em>Données d'entrée&nbsp;</em></strong><br><ul class="iconlist none"><li>Saisir un nombre : 9</li></ul><br><strong><em>Données de sortie</em></strong><br><ul class="iconlist none"><li>La racine carrée du 9 = 3</li></ul></div></div>

# %%
#solution

# %% [markdown]
# <strong><div class="fancy-title title-bottom-border"><h3><span>Exercice 7</span></h3></div></strong>
# <p>Écrivez un programme pour saisir deux angles de l'utilisateur et trouver le troisième angle du triangle.</p>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <div class="style-msg2"><div class="msgtitle">Exemple :</div><div class="sb-msg"><strong><em>Données d'entrée&nbsp;</em></strong><br><ul class="iconlist none"><li>Angles : 50 30</li></ul><br><strong><em>Données de sortie</em></strong><br><ul class="iconlist none"><li>3ème angle = 100</li></ul></div></div>

# %%
#solution

# %% [markdown]
# <strong><div class="fancy-title title-bottom-border"><h3><span>Exercice 8</span></h3></div></strong>
# <p>Écrivez un programme pour saisir la base et la hauteur d'un triangle et trouver la surface du triangle donné.</p>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <div class="style-msg2"><div class="msgtitle">Exemple :</div><div class="sb-msg"><strong><em>Données d'entrée&nbsp;</em></strong><br><ul class="iconlist none"><li>Saisir la base : 15</li><li>Saisir la hauteur : 30</li></ul><br><strong><em>Données de sortie</em></strong><br><ul class="iconlist none"><li>La surface est = 225</li></ul></div></div>

# %%
#solution

# %% [markdown]
# <strong><div class="fancy-title title-bottom-border"><h3><span>Exercice 9</span></h3></div></strong>
# Écrivez un programme pour saisir les notes de cinq matières d'un élève et calculer le total, la moyenne et le pourcentage de toutes les matières.
# <div class="style-msg2"><div class="msgtitle">Exemple :</div><div class="sb-msg"><strong><em>Données d'entrée&nbsp;</em></strong><br><ul class="iconlist none"><li>Saisir les notes de 5 matières : 10 11 12 13 14</li></ul><br><strong><em>Données de sortie</em></strong><br><ul class="iconlist none"><li>Total = 60</li><li>Moyenne = 12</li><li>Pourcentage = 12.00 %</li></ul></div></div>

# %%
#solution

# %% [markdown]
# <strong><div class="fancy-title title-bottom-border"><h3><span>Exercice 10</span></h3></div></strong>
# <p>Écrivez un programme pour saisir le côté d'un triangle équilatéral de l'utilisateur et trouvez la surface du triangle donné.</p>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <div class="style-msg2"><div class="msgtitle">Exemple :</div><div class="sb-msg"><strong><em>Données d'entrée&nbsp;</em></strong><br><ul class="iconlist none"><li>Saisir le côté d'un triangle : 30</li></ul><br><strong><em>Données de sortie</em></strong><br><ul class="iconlist none"><li>La surface du triangle = 389.71</li></ul></div></div>

# %%
#solution
