# %% [markdown]
# # Project - Guess Random Number

# %% [markdown]
# ### The game
#
# - The computer generates a random number from 1 to 100.
# - The user should guess it.
# - If the user guesses correct, it should print how many guesses the user used and end.
# - If the user guesses too low, print it.
# - If the user guesses too big, print it.

# %% [markdown]
# ### Step 1: Import
#
# - You need to import a randrange to generate a random number from 1 to 100 (both included).

# %% [markdown]
# #### DOUBLE CLICK HERE TO GET HELP TO IMPORT
#
# <!--
#
# from random import randrange
#
# -->

# %%
from random import randrange

# %% [markdown]
# ### Step 2: Genrate a random number
#
# You need to generate a random number form 1 to 100 (both included).

# %% [markdown]
# #### DOUBLE CLICK HERE TO GET HELP
#
# <!--
#
# num = randrange(1, 101)
#
# -->

# %%
random_number = randrange(100) + 1

# %% [markdown]
# ### Step 3: Keep track of how many guesses
#
# You want to know how many guesses the user has used.

# %% [markdown]
# #### DOUBLE CLICK HERE TO GET HELP
#
# <!--
#
# Create a variable assigned to 0 as before we start the user has guessed 0 times.
#
# guesses = 0
#
# -->

# %%
guesses = 0

# %% [markdown]
# ### 4: Main loop
#
# - Start by writing a loop that takes a guess from the user.
# - Then make a validation that the input is the correct range (1 - 100)
#
# To test your loop you can use `break` after your code, this way you don't end up in an infinite loop.

# %% [markdown]
# #### DOUBLE CLICK HERE TO GET HELP
#
# <!--
#
# 1. We want to use a while loop.
# 2. We take input from the user and convert it to an int.
# 3. Then we check if the guess is in range, if not, start again
#
# while True:
#
#     guess = int(input("What is your guess (1-100)? "))
#
#     if guess < 1 or guess > 100:
#         print('Out of bounds!')
#         continue
#
#     break  # This is to end the loop while testing
#
# -->

# %%
while True:
    guess_str = input('What is your guess (1-100): ')
    guess = int(guess_str)
    
    if guess < 1:
        print('Out of bounds')
        continue
    if guess > 100:
        print('Out of bounds')
        continue
    
    break
# Out:
# What is your guess (1-100): 0
# Out of bounds
# What is your guess (1-100): 120
# Out of bounds
# What is your guess (1-100): 101
# Out of bounds
# What is your guess (1-100): 100

# %% [markdown]
# ### Step 5: The full code
#
# - Now you only need to increment the variable `guesses` (increment means add 1 to it).
# - Then check if guess is correct, if so, print it and break out of the loop.
# - Then check if guess is too low or too big, print it to the user.

# %%
random_number = randrange(100) + 1

guesses = 0

print("I'm thinking of a number between 1 and 100.")

while True:
    guess_str = input('What is your guess (1-100): ')
    guess = int(guess_str)
    
    if guess < 1:
        print('Out of bounds')
        continue
    if guess > 100:
        print('Out of bounds')
        continue
    
    guesses += 1
    
    if guess == random_number:
        print('Awesome! You guessed it!')
        print('You used', guesses, 'guesses')
        break
    elif guess < random_number:
        print('Too low')
    elif guess > random_number:
        print('Too high')
# Out:
# I'm thinking of a number between 1 and 100.
# What is your guess (1-100): 50
# Too high
# What is your guess (1-100): 25
# Too low
# What is your guess (1-100): 35
# Too high
# What is your guess (1-100): 30
# Too low
# What is your guess (1-100): 33
# Awesome! You guessed it!
# You used 5 guesses
