# %% [markdown]
# <a href="https://colab.research.google.com/github/yahia-kplr/Fondamentaux-Python_fr/blob/main/Jour_03/04-Randomness.ipynb" target="_blank"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Randomness / NEED-TO-KNOW

# %% [markdown]
# ### Qu'est-ce que le hasard ?
#
# - Découvrons-le
# - Explorez plus dans [docs](https://docs.python.org/3/library/random.html)
#
#
# ``` Python
# à partir d'une importation aléatoire
#
# imprimer(randrange(10))
# ```

# %%
from random import randrange

# %%
randrange(10)
# Out:
# 9

# %% [markdown]
# ### Mélanger une liste
#
# ``` Python
# à partir d'une importation aléatoire aléatoire
#
# l = ['Albert', 'Niels', 'Erwin']
#
# shuffle(l)
# ```

# %%
l = ['Albert', 'Niels', 'Erwin']
l
# Out:
# ['Albert', 'Niels', 'Erwin']

# %%
from random import shuffle

# %%
shuffle(l)
l
# Out:
# ['Erwin', 'Albert', 'Niels']

# %% [markdown]
# ### Obtenir un élément aléatoire de la liste
#
# ``` Python
# du choix d'importation aléatoire
#
# l = ['Albert', 'Niels', 'Erwin']
#
# choix(l)
# ```

# %%
from random import choice

# %%
l = ['Albert', 'Niels', 'Erwin']

choice(l)
# Out:
# 'Niels'

# %% [markdown]
# ### Obtenir une clé aléatoire de dict
#
# ``` Python
# du choix d'importation aléatoire
#
# d = {'clé-1' : 'valeur-1', 'clé-2' : 'valeur-2', 'clé-3' : 'valeur-3'}
#
# choix(liste(d))
# ```

# %%
d = {'key-1': 'value-1', 'key-2': 'value-2', 'key-3': 'value-3'}

choice(list(d))
# Out:
# 'key-2'
