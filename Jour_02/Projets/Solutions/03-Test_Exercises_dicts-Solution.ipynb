# %% [markdown]
# <a href="https://colab.research.google.com/github/kplr-training/Fondamentaux-Python/blob/main/Jour_02/Projets/Solutions/03-Test_Exercises_dicts-Solution.ipynb" target="_blank"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Test Exercises

# %% [markdown]
# ### Exercise 1
# 1. Create the dictionary (dict) `d = {'key': 'value'}`
# 2. Access value `value`
# 3. Change value `value` to `VALUE`

# %%
d = {'key': 'value'}
d
# Out:
# {'key': 'value'}

# %%
d['key']
# Out:
# 'value'

# %%
d['key'] = 'VALUE'
d
# Out:
# {'key': 'VALUE'}

# %%
d = {'key': 'value'}
d['key'] = d['key'].upper()
d
# Out:
# {'key': 'VALUE'}

# %% [markdown]
# ### Exercise 2
#
# 1. Create an empty dictionary (dict)
# 2. Add a key-value pair
# 3. What is the key and a value in a dictionary (dict)?

# %%
d = {}
d['Name'] = 'Cole'
d
# Out:
# {'Name': 'Cole'}

# %% [markdown]
# ### Exercise 3
#
# 1. Create dictionary (dict) `{'posts': 0, 'pages': 0}`
# 2. Update `posts` to be 100
# 3. Get the value of `posts` and add 10 and store it to `pages`
# - HINT: end result should be `{'posts': 100, 'pages': 110}`

# %%
d = {'posts': 0, 'pages': 0}
d
# Out:
# {'posts': 0, 'pages': 0}

# %%
d['posts'] = 100
d
# Out:
# {'posts': 100, 'pages': 0}

# %%
d['pages'] = d['posts'] + 10
d
# Out:
# {'posts': 100, 'pages': 110}

# %%
posts = d['posts']
posts += 10
d['pages'] = posts
d
# Out:
# {'posts': 100, 'pages': 110}

# %% [markdown]
# ### Exercise 4
# 1. Create dictionary (dict) `{'i': 2, 'b': ['one', 'two']}`
# 2. Change `'one'` to `1`

# %%
d = {'i': 2, 'b': ['one', 'two']}
d
# Out:
# {'i': 2, 'b': ['one', 'two']}

# %%
type(d['b'])
# Out:
# list

# %%
d['b'][0] = 1
d
# Out:
# {'i': 2, 'b': [1, 'two']}
