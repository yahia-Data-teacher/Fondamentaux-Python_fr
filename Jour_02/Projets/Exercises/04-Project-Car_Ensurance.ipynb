# %% [markdown]
# <a href="https://colab.research.google.com/github/yahia-kplr/Fondamentaux-Python_fr/blob/main/Jour_02/Projets/Exercises/04-Project-Car_Ensurance.ipynb" target="_blank"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project - Car Ensurance
# ### Goal
# - Car ensurance calculation based on the following decision tree

# %% [markdown]
# ![texte alternatif](../img/DecisionTree.png "Titre")

# %% [markdown]
# ### Description- Il s'agit d'une compagnie d'assurance automobile fictive appelée Car Crash- Ils calculent le prix annuel de l'assurance en fonction du prix actuel du marché de la voiture- Étant donné le prix du marché : market_price- Ensuite, le prix d'assurance annuel est de 9 % du prix du marché s'il s'agit d'un homme de plus de 26 ans.- Comme nous le voyons dans l'arbre de décision, nous avons 4 calculs de prix possibles.- Créer un programme, qui prend en compte et sur la base de cela calculé le prix correct pour les 4 cas
