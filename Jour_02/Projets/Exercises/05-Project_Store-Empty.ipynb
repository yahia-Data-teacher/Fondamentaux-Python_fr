# %% [markdown]
# <a href="https://colab.research.google.com/github/yahia-kplr/Fondamentaux-Python_fr/blob/main/Jour_02/Projets/Exercises/05-Project_Store-Empty.ipynb" target="_blank"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project Store
#
# You will start to sell items from your awesome store with an interactive display.

# %% [markdown]
# ### Étape 1 : ConfigurationVous comptez les articles vendus et vendez les trois articles suivants.1. "pomme"2. "poire"3. "Orange"Pour garder une trace du nombre d'articles que vous vendez, vous pouvez utiliser un dictionnaire.Le dictionnaire peut utiliser les articles comme clés et le nombre d'articles vendus comme valeur.``` Pythonarticles_vendus = {'pomme' : 0}```Créez un dictionnaire avec les trois articles que vous vendez.

# %% [markdown]
# ### Étape 2 : Invite client- Un client devrait être demandé quel article acheter et combien.- Ensuite, vous devez mettre à jour le nombre d'articles vendus dans le dictionnaire `sold_items`Si vous écrivez tout le code dans une cellule, vous pouvez l'exécuter pour chaque client entrant dans le magasin.

# %% [markdown]
# #### CLIQUEZ POUR UN CONSEIL<!--Pour obtenir l'entrée du client, utilisez la fonction intégrée input()N'oubliez pas de convertir l'entrée en nombres entiers.-->

# %% [markdown]
# ### Étape 3 : État- Vous pouvez maintenant imprimer le nombre d'articles que vous avez vendus.- En outre, vous pouvez imprimer le nombre total d'articles.
