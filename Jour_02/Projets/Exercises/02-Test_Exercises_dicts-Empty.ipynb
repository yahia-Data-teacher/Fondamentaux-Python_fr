# %% [markdown]
# <a href="https://colab.research.google.com/github/yahia-kplr/Fondamentaux-Python_fr/blob/main/Jour_02/Projets/Exercises/02-Test_Exercises_dicts-Empty.ipynb" target="_blank"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Test Exercises

# %% [markdown]
# ### Exercice 1
# 1. Créez le dictionnaire (dict) `d = {'key': 'value'}`
# 2. Accéder à la valeur `value`
# 3. Remplacez la valeur `value` par `VALUE`

# %% [markdown]
# ### Exercice 2
#
# 1. Créer un dictionnaire vide (dict)
# 2. Ajouter une paire clé-valeur
# 3. Quelle est la clé et une valeur dans un dictionnaire (dict) ?

# %% [markdown]
# ### Exercice 3
#
# 1. Créer un dictionnaire (dict) `{'posts' : 0, 'pages' : 0}`
# 2. Mettez à jour les "messages" à 100
# 3. Obtenez la valeur de `posts` et ajoutez 10 et stockez-la dans `pages`
# - ASTUCE : le résultat final devrait être `{'posts' : 100, 'pages' : 110}`

# %% [markdown]
# ### Exercice 4
# 1. Créer un dictionnaire (dict) `{'i' : 2, 'b' : ['un', 'deux']}`
# 2. Remplacez ''un'' par '1'
