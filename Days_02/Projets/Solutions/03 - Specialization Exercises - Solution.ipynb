# %% [markdown]
# # Specialization Exercises

# %% [markdown]
# ### Exercise 1
# 1. Create tuple `(1, 2, 3)`
# 2. Convert it to a list
#     - HINT: Assign it to a variable and test it with `type()`
# 3. Change first item of the list to `0`

# %%
t = (1, 2, 3)

# %%
l = list(t)
l
# Out:
# [1, 2, 3]

# %%
type(l)
# Out:
# list

# %%
l[0] = 'ONE'
l
# Out:
# ['ONE', 2, 3]

# %% [markdown]
# ### Exercise 2
# 1. Create tuple `(1, 2, 3)`
# 2. Change first item of the tuple to `0`
#     - HINT: It should fail
# 3. Why does it fail?

# %%
t = (1, 2, 3)

# %%
t[0] = 0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/5f/vgbh9pkd4wzf4ysrpf9wsr800000gn/T/ipykernel_46653/191694041.py in <module>
# ----> 1 t[0] = 0
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ### Exercise 3
# 1. Create set `{1, 2, 3, 4}`
# 2. Add item `3`
# 3. What happened and why?
# 4. Add item `5`
# 5. What happened and why?

# %%
s = {1, 2, 3, 4}
s.add(3)
s.add(5)
s
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# ### Exercise 4
#
# 1. Create list `[1, 2, 2, 3, 4, 4]`
# 2. Convert it to set (remember to assign it to variable)
# 3. Convert the set to list (remember to assign it to a variable)
# - HINT: You should end up with list `[1, 2, 3, 4]`

# %%
l = [1, 2, 2, 3, 4, 4]
s = set(l)  # {1, 2, 3, 4}
l2 = list(s)  # [1, 2, 3, 4]
l2
# Out:
# [1, 2, 3, 4]
